# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Health.csv')

# %%
df.dtypes
# Out:
# Country            object
# LifeExpectancy    float64
# FertilityRate     float64
# Population         object
# Region             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         191 non-null    object
#  1   LifeExpectancy  191 non-null    float64
#  2   FertilityRate   191 non-null    float64
#  3   Population      191 non-null    object
#  4   Region          191 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.6+ KB

# %%
df.shape
# Out:
# (191, 5)

# %%
df = df.reset_index(drop=True)
df
# Out:
#                    Country  LifeExpectancy  FertilityRate Population  \
# 0              Afghanistan          51.000           7.81   19701940
# 1                  Albania          74.200           2.47    3121965
# 2                  Algeria          73.200           2.63   31183658
# 3                   Angola          52.600           6.88   15058638
# 4      Antigua and Barbuda          73.900           2.32      77648
# ..                     ...             ...            ...        ...
# 186  Virgin Islands (U.S.)          79.247           2.13     108511
# 187     West Bank and Gaza          73.500           5.57    3223781
# 188         Western Sahara          66.507           3.04     305615
# 189                 Zambia          45.700           6.10   10585220
# 190               Zimbabwe          50.800           4.11   12499981
#
#                          Region
# 0                    South Asia
# 1         Europe & Central Asia
# 2    Middle East & North Africa
# ...

# %%
densidade_demografica = df.sort_values(by = 'LifeExpectancy', ascending=False).reset_index(drop=True)
densidade_demografica_1 = densidade_demografica[['Country', 'LifeExpectancy', 'Region']].query('(Region == "East Asia & Pacific")')
sns.kdeplot(data=densidade_demografica_1, x='LifeExpectancy', shade=True)

plt.title('Distribuição da Expectativa de Vida na Região East Asia & Pacific', fontsize=16, fontweight='bold')
mean_life_expectancy = densidade_demografica_1['LifeExpectancy'].mean()
plt.axvline(mean_life_expectancy, color='blue', linestyle='dashed', linewidth=1)
plt.text(mean_life_expectancy + 0.5, 0.01, 'Média', color='blue', fontsize=12)
plt.tight_layout()


plt.show()

#grafico de densidade baseada nos países com maior expectativa de vida da East Asia & Pacific
# Out:
# <ipython-input-37-12b8176fa23c>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=densidade_demografica_1, x='LifeExpectancy', shade=True)
